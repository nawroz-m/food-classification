# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from PIL import Image
from torchvision import transforms
from torchvision.transforms import InterpolationMode
from torch.utils.data import DataLoader, Dataset, WeightedRandomSampler
import torch.nn.functional as F
from torchsummary import summary
from torch.optim.lr_scheduler import CosineAnnealingLR
from collections import Counter
import time
from sklearn.model_selection import train_test_split

# %%
# Setting for the the trianing 
tr_percentage = 0.30 # train on provided percetage of data from the entire dataset
if torch.cuda.is_available():
    device = 'cuda'
elif torch.backends.mps.is_available():
    device = 'mps'
else:
    device = 'cpu'

print(f"Using device: [{device}]")
print(f'Your are using {tr_percentage*100}% of your dataset')
# Out:
# Using device: [cuda]
# Your are using 30.0% of your dataset

# %%
# Prepare the dataset directories 
# data_path = "food-classification/ifood-2019-fgvc6"
data_path = "/kaggle/input/datasets/hjhgkyo/food-dataset-ifood2019fgvc"
train_data = os.path.join(data_path, 'train_set/train_set')
test_data = os.path.join(data_path, 'val_set/val_set')

train_imgs = os.listdir(train_data) # get all training images files
test_imgs = os.listdir(test_data) # get all training images files
print(f'There are {len(train_imgs)} training and {len(test_imgs)} testing images')
# Out:
# There are 118475 training and 11994 testing images

# %%
# read the labels 
pdf = pd.read_csv(os.path.join(data_path, 'train_labels.csv'))
t_pdf = pd.read_csv(os.path.join(data_path, 'val_labels.csv'))
print(f'Ther are {pdf.isna().sum().sum()} images without labels')
pdf.count()
# Out:
# Ther are 0 images without labels
# img_name    118475
# label       118475
# dtype: int64

# %%
# read the classes value
data_classes = pd.read_csv(os.path.join(data_path, 'class_list.txt'), sep=' ') 
data_classes.columns = ['id', 'name']
NUM_CLASSES = len(data_classes)+1
# plot the all class distributions 
all_classes = pdf['label']

# Stratified sampling to get xx% from each class
# trainable_pdf = pdf.groupby('label', group_keys=False).sample(frac=tr_percentage, random_state=42)
trainable_pdf = (
    pdf.groupby('label', group_keys=False)
    .apply(lambda x: x.sample(
        max(2, int(len(x) * tr_percentage)),
        random_state=42
    ).assign(label=x.name), include_groups=False)
)

# test_pdf = t_pdf.groupby('label', group_keys=False).sample(frac=tr_percentage, random_state=42)
test_pdf = (
    t_pdf.groupby('label', group_keys=False)
    .apply(lambda x: x.sample(
        max(2, int(len(x) * tr_percentage)),
        random_state=42
    ).assign(label=x.name), include_groups=False)
)

print(f'There are {NUM_CLASSES} classes')
print(f'There are {len(trainable_pdf)} images for training and validation')
# Out:
# There are 251 classes
# There are 35424 images for training and validation

# %%
# plot the class distribution
def plot_class_distributions(num_labels, percentage = 100):
    """
    This method will plot the labels distribution passed in the histogram format
    """
    counts = Counter(num_labels)
    min_class = min(counts, key=counts.get)
    max_class = max(counts, key=counts.get)

    print(f"""
        Min class: {min_class}  ––> {counts[min_class]} images
        Max class: {max_class} ––> {counts[max_class]} images 
    """)

    plt.figure(figsize=(12, 5))
    plt.hist(num_labels, bins=NUM_CLASSES, color='skyblue', edgecolor='black', alpha=0.8)
    plt.title(f"""
        Distribution of {percentage}% Labels
        Min class: {min_class}  ––> {counts[min_class]} images
        Max class: {max_class} ––> {counts[max_class]} images 
    """)
    plt.xlabel('Label Value')
    plt.ylabel('Frequency')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# %%
# plot all class distributions 
plot_class_distributions(all_classes)
# Out:
#         Min class: 162  ––> 34 images
#         Max class: 218 ––> 656 images

# %%
# plot the sampled classes distribution
plot_class_distributions(trainable_pdf['label'], tr_percentage*100)
# Out:
#         Min class: 162  ––> 10 images
#         Max class: 218 ––> 196 images

# %%
glb_mean = [0.485, 0.456, 0.406]
glb_std = [0.229, 0.224, 0.225]

# %%
# class RotationDataset(Dataset):
#     def __init__(self, df, dir="train_set/train_set", transform=None):
#         self.df = df
#         self.dir = dir
#         self.transform = transform
#     def __len__(self):
#         return len(self.df)
#     def __getitem__(self, idx):
#         file = self.df.iloc[idx].values
#         img_name = file[0]
#         img = Image.open(os.path.join(data_path, self.dir, img_name))
#         if self.transform:
#             img = self.transform(img)
#         # rotate and get lables
#         rot_label = torch.randint(0, 4, (1,)).item()
#         img = torch.rot90(img, rot_label, dims=[1, 2])
#         return img, rot_label

# %%
class SimCLRDataset(Dataset):
    def __init__(self, df, dir="train_set/train_set", transform=None):
        self.df = df
        self.dir = dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):

        img_name = self.df.iloc[idx].values[0]

        img = Image.open(
            os.path.join(data_path, self.dir, img_name)
        ).convert("RGB")

        img1 = self.transform(img)
        img2 = self.transform(img)

        return img1, img2

# %% [markdown]
# ```
# same image
#     |
#     |
#  ----------------
#  |              |
# crop           crop
# color          blur
# jitter         rotation
#  |              |
# view1          view2
# ```

# %%
# load the ground throught dataset and evaluate against the SSL model
class Myclass(Dataset):
    def __init__(self, df, dir='train_set/train_set', transform=None):
        super().__init__()
        self.df = df 
        self.dir = dir # images directory
        self.transform = transform 
    def __len__(self):
        return len(self.df)
    def __getitem__(self, idx):
        file = self.df.iloc[idx].values
        img_name = file[0]
        label = file[1]
        img = Image.open(os.path.join(data_path, self.dir, img_name))
        if self.transform:
            img = self.transform(img)
        return img, label

# %%
# split the train dataset in training (75%), validation (25%)
training_df, validation_df = train_test_split(
    trainable_pdf,
    test_size=0.25,
    stratify=trainable_pdf['label'],
    random_state=42
)
print(f'{len(training_df)} images for training \n{len(validation_df)} images for validation \n{len(test_pdf)} images for testinng.')
# Out:
# 26568 images for training
# 8856 images for validation
# 3485 images for testinng.

# %%
# Training dataset distribution
plot_class_distributions(training_df['label'], tr_percentage*100)

# Validation dataset distribution
plot_class_distributions(validation_df['label'], tr_percentage*100)

# Testing dataset distribution
plot_class_distributions(test_pdf['label'], tr_percentage*100)
# Out:
#         Min class: 162  ––> 7 images
#         Max class: 218 ––> 147 images
#         Min class: 162  ––> 3 images
#         Max class: 218 ––> 49 images
#         Min class: 116  ––> 2 images
#         Max class: 34 ––> 20 images

# %%
SIZE = 160
train_transform = transforms.Compose([
    transforms.Resize(size=(SIZE+20, SIZE+20), interpolation=InterpolationMode.BICUBIC),
    
    transforms.RandomCrop(SIZE, padding=6),
    transforms.RandomHorizontalFlip(p=0.5), 
    transforms.RandomRotation(degrees=15),

    transforms.ColorJitter(
        brightness=0.3,
        contrast=0.3,
        saturation=0.3,
        hue=0.03
    ),
    transforms.ToTensor(),
    transforms.Normalize(mean=glb_mean, std=glb_std),
])
val_transform = transforms.Compose([  
    transforms.Resize(size=(SIZE, SIZE), interpolation=InterpolationMode.BICUBIC),
    transforms.ToTensor(),
    transforms.Normalize(mean=glb_mean, std=glb_std),
])

# %%
simclr_transform = transforms.Compose([
    transforms.RandomResizedCrop(
        SIZE,
        scale=(0.5, 1.0),
        interpolation=InterpolationMode.BICUBIC
    ),

    transforms.RandomHorizontalFlip(p=0.5),

    transforms.RandomRotation(degrees=15),

    transforms.RandomApply(
        [
            transforms.ColorJitter(
                brightness=0.5,
                contrast=0.5,
                saturation=0.5,
                hue=0.05
            )
        ],
        p=0.8
    ),

    transforms.RandomGrayscale(p=0.2),

    transforms.RandomApply(
        [
            transforms.GaussianBlur(kernel_size=15)
        ],
        p=0.5
    ),

    transforms.ToTensor(),

    transforms.Normalize(
        mean=glb_mean,
        std=glb_std
    )
])

# %%
# Get the training, validation, and testing datas
clf_train_data = Myclass(training_df, 'train_set/train_set', train_transform)
clf_val_data = Myclass(validation_df, 'train_set/train_set', val_transform)
clf_test_data = Myclass(test_pdf, 'val_set/val_set', val_transform)
len(clf_train_data), len(clf_val_data), len(clf_test_data)
# Out:
# (26568, 8856, 3485)

# %%
# Get the training, validation, and testing datas
train_data = SimCLRDataset(training_df, 'train_set/train_set', simclr_transform)
val_data = SimCLRDataset(validation_df, 'train_set/train_set', val_transform)
test_data = SimCLRDataset(test_pdf, 'val_set/val_set', val_transform)
len(train_data), len(val_data), len(test_data)
# Out:
# (26568, 8856, 3485)

# %%
# Handle class imbalance 

counts = Counter(training_df['label']) # calculate class count

weights = []
for c in range(251):
    cnt = max(counts[c], 1) # to prevent division by zero if 0 class 
    weights.append(1.0 / np.sqrt(cnt)) # SQRT applied to make it more softner instead of raw count

weights = torch.tensor(weights, dtype=torch.float32)
weights = weights / weights.sum() * len(weights) # normalize the class weight
weight=weights.to(device)


# WeightedRandomSampler is useful when:

# Map these normalized weights to every row pdf
sample_weights = [weights[label].item() for label in training_df['label']]

# Create sampler
sampler = WeightedRandomSampler(
    weights=sample_weights,
    num_samples=len(sample_weights),
    replacement=True
)
len(counts), len(weights)
# Out:
# (251, 251)

# %%
# Add data loader 
BATCH_SIZE = 64
PIN_MEMORY = True if device == 'cuda' or device == 'mps' else False
NUM_WORKERS = 0
clf_train_loader = DataLoader(clf_train_data,
                          batch_size=BATCH_SIZE,
                          shuffle=False, 
                          sampler=sampler,
                          drop_last=True, 
                          pin_memory=PIN_MEMORY,
                          num_workers=NUM_WORKERS)
clf_val_loader = DataLoader(clf_val_data, batch_size=BATCH_SIZE, shuffle=False, drop_last=False, pin_memory=PIN_MEMORY, num_workers=NUM_WORKERS)
clf_test_loader = DataLoader(clf_test_data, batch_size=BATCH_SIZE, shuffle=False, drop_last=False, pin_memory=PIN_MEMORY, num_workers=NUM_WORKERS)
print(f"There are \n {len(clf_train_loader)} training batches \n {len(clf_val_loader)} validation batches \n {len(clf_test_loader)} testing batches")
# Out:
# There are
#  415 training batches
#  139 validation batches
#  55 testing batches

# %%
# Add data loader 
BATCH_SIZE = 64
PIN_MEMORY = True if device == 'cuda' or device == 'mps' else False
NUM_WORKERS = 0
train_loader = DataLoader(train_data,
                          batch_size=BATCH_SIZE,
                          shuffle=False, 
                          sampler=sampler,
                          drop_last=True, 
                          pin_memory=PIN_MEMORY,
                          num_workers=NUM_WORKERS)
val_loader = DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=False, drop_last=False, pin_memory=PIN_MEMORY, num_workers=NUM_WORKERS)
test_loader = DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=False, drop_last=False, pin_memory=PIN_MEMORY, num_workers=NUM_WORKERS)
print(f"There are \n {len(train_loader)} training batches \n {len(val_loader)} validation batches \n {len(test_loader)} testing batches")
# Out:
# There are
#  415 training batches
#  139 validation batches
#  55 testing batches

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_ch, out_ch, stride=1):
        super().__init__() 
        
        self.doubleConve = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, stride=stride, padding=1, bias=False), # No bias also save GPU
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True), # Faster with GPU
            nn.Conv2d(out_ch, out_ch, 3, stride=1, padding=1, bias=False), 
            nn.BatchNorm2d(out_ch),
        )
        
        self.skip = nn.Identity()
        if in_ch != out_ch or stride !=1:
            self.skip = nn.Sequential(
                nn.Conv2d(in_ch, out_ch, 1, stride=stride, padding=0, bias=False), 
                nn.BatchNorm2d(out_ch),
            ) 
        self.relu = nn.ReLU(inplace=True)
    def forward(self, x):
        residual = self.skip(x)
        out = self.doubleConve(x)
        out = out + residual 
        out = self.relu(out) # added residual
        return out

# %%
class ResNet(nn.Module):
    def __init__(self):
        super().__init__()
        # input layer
        self.prep = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True)
        )
        # Encoder
        self.block1 = nn.Sequential(ResidualBlock(32, 32, stride=1), ResidualBlock(32, 32, stride=1))      
        self.block2 = nn.Sequential(ResidualBlock(32, 64, stride=2), ResidualBlock(64, 64, stride=1))      
        self.block3 = nn.Sequential(ResidualBlock(64, 128, stride=2), ResidualBlock(128, 128, stride=1))      
        self.block4 = nn.Sequential(ResidualBlock(128, 256, stride=2), ResidualBlock(256, 256, stride=1))      
        self.block5 = nn.Sequential(ResidualBlock(256, 512, stride=2))      

    def forward(self, x): 
        x = self.prep(x)
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.block4(x)
        x = self.block5(x)
        return x

resnet = ResNet().to(device)
# summary(resnet, input_size=(3, 64, 64))

# %%
class SimCLRNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = ResNet()
        self.head = nn.Sequential(
            nn.AdaptiveAvgPool2d((1,1)),
            nn.Flatten(),
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, 128),
        )
    def forward(self, x):
        x = self.encoder(x)
        x = self.head(x)
        x = F.normalize(x, dim=1)
        return x
simCLRNet = SimCLRNet().to(device)
base_model = simCLRNet
# prevents the GPU from wasting time reading and writing intermediate steps to memory.
simCLRNet = torch.compile(simCLRNet) # Fuses the graph for massive speedups

# %%
summary(simCLRNet, input_size=(3, 160, 160))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 80, 80]             864
#        BatchNorm2d-2           [-1, 32, 80, 80]              64
#               ReLU-3           [-1, 32, 80, 80]               0
#           Identity-4           [-1, 32, 80, 80]               0
#             Conv2d-5           [-1, 32, 80, 80]           9,216
#        BatchNorm2d-6           [-1, 32, 80, 80]              64
#               ReLU-7           [-1, 32, 80, 80]               0
#             Conv2d-8           [-1, 32, 80, 80]           9,216
#        BatchNorm2d-9           [-1, 32, 80, 80]              64
#              ReLU-10           [-1, 32, 80, 80]               0
#     ResidualBlock-11           [-1, 32, 80, 80]               0
#          Identity-12           [-1, 32, 80, 80]               0
#            Conv2d-13           [-1, 32, 80, 80]           9,216
#       BatchNorm2d-14           [-1, 32, 80, 80]              64
#              ReLU-15           [-1, 32, 80, 80]               0
#            Conv2d-16           [-1, 32, 80, 80]           9,216
#       BatchNorm2d-17           [-1, 32, 80, 80]              64
#              ReLU-18           [-1, 32, 80, 80]               0
#     ResidualBlock-19           [-1, 32, 80, 80]               0
#            Conv2d-20           [-1, 64, 40, 40]           2,048
#       BatchNorm2d-21           [-1, 64, 40, 40]             128
#            Conv2d-22           [-1, 64, 40, 40]          18,432
#       BatchNorm2d-23           [-1, 64, 40, 40]             128
#              ReLU-24           [-1, 64, 40, 40]               0
#            Conv2d-25           [-1, 64, 40, 40]          36,864
#       BatchNorm2d-26           [-1, 64, 40, 40]             128
#              ReLU-27           [-1, 64, 40, 40]               0
#     ResidualBlock-28           [-1, 64, 40, 40]               0
#          Identity-29           [-1, 64, 40, 40]               0
#            Conv2d-30           [-1, 64, 40, 40]          36,864
#       BatchNorm2d-31           [-1, 64, 40, 40]             128
#              ReLU-32           [-1, 64, 40, 40]               0
#            Conv2d-33           [-1, 64, 40, 40]          36,864
#       BatchNorm2d-34           [-1, 64, 40, 40]             128
#              ReLU-35           [-1, 64, 40, 40]               0
#     ResidualBlock-36           [-1, 64, 40, 40]               0
#            Conv2d-37          [-1, 128, 20, 20]           8,192
#       BatchNorm2d-38          [-1, 128, 20, 20]             256
#            Conv2d-39          [-1, 128, 20, 20]          73,728
#       BatchNorm2d-40          [-1, 128, 20, 20]             256
#              ReLU-41          [-1, 128, 20, 20]               0
#            Conv2d-42          [-1, 128, 20, 20]         147,456
#       BatchNorm2d-43          [-1, 128, 20, 20]             256
#              ReLU-44          [-1, 128, 20, 20]               0
#     ResidualBlock-45          [-1, 128, 20, 20]               0
#          Identity-46          [-1, 128, 20, 20]               0
#            Conv2d-47          [-1, 128, 20, 20]         147,456
#       BatchNorm2d-48          [-1, 128, 20, 20]             256
#              ReLU-49          [-1, 128, 20, 20]               0
#            Conv2d-50          [-1, 128, 20, 20]         147,456
#       BatchNorm2d-51          [-1, 128, 20, 20]             256
#              ReLU-52          [-1, 128, 20, 20]               0
#     ResidualBlock-53          [-1, 128, 20, 20]               0
#            Conv2d-54          [-1, 256, 10, 10]          32,768
#       BatchNorm2d-55          [-1, 256, 10, 10]             512
#            Conv2d-56          [-1, 256, 10, 10]         294,912
#       BatchNorm2d-57          [-1, 256, 10, 10]             512
#              ReLU-58          [-1, 256, 10, 10]               0
#            Conv2d-59          [-1, 256, 10, 10]         589,824
#       BatchNorm2d-60          [-1, 256, 10, 10]             512
#              ReLU-61          [-1, 256, 10, 10]               0
#     ResidualBlock-62          [-1, 256, 10, 10]               0
#          Identity-63          [-1, 256, 10, 10]               0
#            Conv2d-64          [-1, 256, 10, 10]         589,824
#       BatchNorm2d-65          [-1, 256, 10, 10]             512
#              ReLU-66          [-1, 256, 10, 10]               0
#            Conv2d-67          [-1, 256, 10, 10]         589,824
#       BatchNorm2d-68          [-1, 256, 10, 10]             512
#              ReLU-69          [-1, 256, 10, 10]               0
#     ResidualBlock-70          [-1, 256, 10, 10]               0
#            Conv2d-71            [-1, 512, 5, 5]         131,072
#       BatchNorm2d-72            [-1, 512, 5, 5]           1,024
#            Conv2d-73            [-1, 512, 5, 5]       1,179,648
#       BatchNorm2d-74            [-1, 512, 5, 5]           1,024
#              ReLU-75            [-1, 512, 5, 5]               0
#            Conv2d-76            [-1, 512, 5, 5]       2,359,296
#       BatchNorm2d-77            [-1, 512, 5, 5]           1,024
#              ReLU-78            [-1, 512, 5, 5]               0
#     ResidualBlock-79            [-1, 512, 5, 5]               0
#            ResNet-80            [-1, 512, 5, 5]               0
# AdaptiveAvgPool2d-81            [-1, 512, 1, 1]               0
#           Flatten-82                  [-1, 512]               0
#            Linear-83                  [-1, 256]         131,328
#              ReLU-84                  [-1, 256]               0
#            Linear-85                  [-1, 128]          32,896
#         SimCLRNet-86                  [-1, 128]               0
# ================================================================
# Total params: 6,632,352
# Trainable params: 6,632,352
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.29
# Forward/backward pass size (MB): 53.92
# Params size (MB): 25.30
# Estimated Total Size (MB): 79.51
# ----------------------------------------------------------------

# %%
class NTXentLoss(nn.Module):
    def __init__(self, temperature=0.5):
        super().__init__()
        self.temperature = temperature

    def forward(self, z1, z2):

        batch_size = z1.shape[0]

        z = torch.cat([z1, z2], dim=0)

        similarity = torch.matmul(
            z, z.T
        ) / self.temperature


        mask = torch.eye(
            2 * batch_size,
            device=z.device,
            dtype=torch.bool
        )


        # use a float16-safe minimum value
        similarity = similarity.masked_fill(
            mask,
            torch.finfo(similarity.dtype).min
        )


        targets = torch.arange(
            batch_size,
            device=z.device
        )

        targets = torch.cat(
            [targets + batch_size, targets]
        )


        loss = F.cross_entropy(
            similarity,
            targets
        )

        return loss

# %%
# Setup the model compiler
EPOCHS = 50
optimizer = torch.optim.AdamW(simCLRNet.parameters(), lr=1e-3, weight_decay=1e-4) 

# loss method 
loss_fun = NTXentLoss()

# per-epoch stepping
scheduler = CosineAnnealingLR(optimizer, T_max=EPOCHS, eta_min=1e-6)

# %%
img1, img2 = next(iter(train_loader))

img1 = img1.to(device)
img2 = img2.to(device)

z1 = simCLRNet(img1)
z2 = simCLRNet(img2)

print(z1.shape)
print(z2.shape)
# Out:
# torch.Size([64, 128])
# torch.Size([64, 128])

# %%
loss = loss_fun(z1,z2)

print(loss)
# Out:
# tensor(4.8216, device='cuda:0', grad_fn=<NllLossBackward0>)

# %%
# Create a training method for non-labeled data
# avoid gradient magnitudes from being flushed to zero(underfilowing) using 16-bit floating-poin
scaler = torch.amp.GradScaler('cuda') # also speed up training 
def train_model(model, dataloader, loss_fun, optimizer):
  training_loss = 0
  model.train()
  for batch, (X1, X2) in enumerate(dataloader):
    X1, X2 = X1.to(device), X2.to(device) 
    # clears the gradient buffers by setting them to None instead of filling them with zeros 
    optimizer.zero_grad(set_to_none=True) # reduce memory consumption and speed up training 

    # Enable AMP for the forward pass
    with torch.autocast(device_type='cuda', dtype=torch.float16): 
        z1 = model(X1) # (batch_size,128)
        z2 = model(X2) # (batch_size,128)
        loss = loss_fun(z1, z2) # calculate the loss

    # Scale loss and backpropagate
    scaler.scale(loss).backward() # comput the gradient
    scaler.step(optimizer) # update the weight
    scaler.update() # update the scaler for the next iteration
      
    training_loss += loss.item() 
    
    if (batch+1 == len(dataloader)):
      print(f'Batch {batch+1}/{len(dataloader)} | Loss: {loss.item():.4f}') 
  return training_loss/len(dataloader)

# %%
# Create a validation method
def validate_model(model, dataloader, loss_fun, epoch):
  model.eval()
  val_loss= 0
  with torch.no_grad():
    for batch, (X1, X2) in enumerate(dataloader):
      X1, X2 = X1.to(device), X2.to(device) 

      # Enable AMP for the forward pass
      with torch.autocast(device_type='cuda', dtype=torch.float16):
            z1 = model(X1) # (batch_size,128)
            z2 = model(X2) # (batch_size,128)
            loss = loss_fun(z1, z2) # calculate the loss 
          
      val_loss += loss.item()  
  return val_loss/len(dataloader)

# %%
output_path = "/kaggle/working"
history = {
    "train_loss": [], 
    "val_loss": [], 
    "lr": [], 
}
best_val_loss = float('inf')

patience, epochs_no_improve = 10, 0 
start_train_time = time.time()
for i in range(EPOCHS):
    print(f'Epoch {i+1}:')
    tr_loss = train_model(simCLRNet, train_loader, loss_fun, optimizer)
    history['train_loss'].append(tr_loss) 
    scheduler.step()

    val_loss = validate_model(simCLRNet, val_loader, loss_fun, i+1)
    history['val_loss'].append(val_loss) 
    history['lr'].append(optimizer.param_groups[-1]['lr'])
    

    print(f"""
    tr loss [{tr_loss:.4f}] | val loss [{val_loss:.4f}] | lr [{optimizer.param_groups[-1]['lr']:.6f}]
    """) 

    # Save only weights of the best model 
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        epochs_no_improve = 0

        torch.save(
            base_model.state_dict(),
            f'{output_path}/simCLRNet_0_best_model_weights.pth'
        )

        print("Best model saved!")
    else:
        epochs_no_improve += 1
        if epochs_no_improve >= patience:
            print(f"Early stopping at epoch {i+1}")
            break
torch.save(base_model.state_dict(), f'{output_path}/simCLRNet_0_last_model.pth')
print(f'Last model saved correctly')
end_train_time = time.time()
print(f'End training after {(end_train_time - start_train_time)/60:.4f} minutes')
# Out:
# Epoch 1:
# Batch 415/415 | Loss: 3.6017
#
#     tr loss [4.0001] | val loss [3.3229] | lr [0.000999]
#
# Best model saved!
# Epoch 2:
# Batch 415/415 | Loss: 3.4407
#
#     tr loss [3.5138] | val loss [3.1743] | lr [0.000996]
#
# Best model saved!
# Epoch 3:
# Batch 415/415 | Loss: 3.3450
#
#     tr loss [3.4028] | val loss [3.1427] | lr [0.000991]
#
# Best model saved!
# Epoch 4:
# Batch 415/415 | Loss: 3.3044
#
#     tr loss [3.3397] | val loss [3.1040] | lr [0.000984]
#
# Best model saved!
# Epoch 5:
# Batch 415/415 | Loss: 3.3626
#
#     tr loss [3.3030] | val loss [3.1113] | lr [0.000976]
#
# Epoch 6:
# Batch 415/415 | Loss: 3.2907
#
#     tr loss [3.2806] | val loss [3.0993] | lr [0.000965]
#
# Best model saved!
# Epoch 7:
# Batch 415/415 | Loss: 3.2596
#
#     tr loss [3.2595] | val loss [3.1245] | lr [0.000952]
#
# Epoch 8:
# Batch 415/415 | Loss: 3.2518
#
#     tr loss [3.2461] | val loss [3.1052] | lr [0.000938]
#
# Epoch 9:
# Batch 415/415 | Loss: 3.2323
#
#     tr loss [3.2329] | val loss [3.1206] | lr [0.000922]
#
# Epoch 10:
# Batch 415/415 | Loss: 3.2159
#
#     tr loss [3.2225] | val loss [3.0471] | lr [0.000905]
#
# Best model saved!
# Epoch 11:
# Batch 415/415 | Loss: 3.1895
#
#     tr loss [3.2131] | val loss [3.0754] | lr [0.000885]
#
# Epoch 12:
# Batch 415/415 | Loss: 3.2152
#
#     tr loss [3.2041] | val loss [3.0549] | lr [0.000865]
#
# Epoch 13:
# Batch 415/415 | Loss: 3.1758
#
#     tr loss [3.1969] | val loss [3.0451] | lr [0.000842]
#
# Best model saved!
# Epoch 14:
# Batch 415/415 | Loss: 3.1622
#
#     tr loss [3.1871] | val loss [3.0473] | lr [0.000819]
#
# Epoch 15:
# Batch 415/415 | Loss: 3.2341
#
#     tr loss [3.1782] | val loss [3.0411] | lr [0.000794]
#
# Best model saved!
# Epoch 16:
# Batch 415/415 | Loss: 3.1280
#
#     tr loss [3.1699] | val loss [3.0464] | lr [0.000768]
#
# Epoch 17:
# Batch 415/415 | Loss: 3.1480
#
#     tr loss [3.1676] | val loss [3.0305] | lr [0.000741]
#
# Best model saved!
# Epoch 18:
# Batch 415/415 | Loss: 3.1830
#
#     tr loss [3.1619] | val loss [3.0190] | lr [0.000713]
#
# Best model saved!
# Epoch 19:
# Batch 415/415 | Loss: 3.1357
#
#     tr loss [3.1553] | val loss [3.0217] | lr [0.000684]
#
# Epoch 20:
# Batch 415/415 | Loss: 3.1697
#
#     tr loss [3.1485] | val loss [3.0277] | lr [0.000655]
#
# Epoch 21:
# Batch 415/415 | Loss: 3.1451
#
#     tr loss [3.1445] | val loss [3.0072] | lr [0.000625]
#
# Best model saved!
# Epoch 22:
# Batch 415/415 | Loss: 3.1296
#
#     tr loss [3.1413] | val loss [3.0099] | lr [0.000594]
#
# Epoch 23:
# Batch 415/415 | Loss: 3.1373
#
#     tr loss [3.1353] | val loss [3.0048] | lr [0.000563]
#
# Best model saved!
# Epoch 24:
# Batch 415/415 | Loss: 3.1589
#
#     tr loss [3.1330] | val loss [3.0202] | lr [0.000532]
#
# Epoch 25:
# Batch 415/415 | Loss: 3.1339
#
#     tr loss [3.1265] | val loss [3.0076] | lr [0.000500]
#
# Epoch 26:
# Batch 415/415 | Loss: 3.1255
#
#     tr loss [3.1237] | val loss [3.0089] | lr [0.000469]
#
# Epoch 27:
# Batch 415/415 | Loss: 3.1027
#
#     tr loss [3.1213] | val loss [2.9990] | lr [0.000438]
#
# Best model saved!
# Epoch 28:
# Batch 415/415 | Loss: 3.0983
#
#     tr loss [3.1166] | val loss [3.0096] | lr [0.000407]
#
# Epoch 29:
# Batch 415/415 | Loss: 3.1323
#
#     tr loss [3.1118] | val loss [2.9952] | lr [0.000376]
#
# Best model saved!
# Epoch 30:
# Batch 415/415 | Loss: 3.1213
#
#     tr loss [3.1081] | val loss [3.0063] | lr [0.000346]
#
# Epoch 31:
# Batch 415/415 | Loss: 3.0828
#
#     tr loss [3.1072] | val loss [2.9901] | lr [0.000317]
#
# Best model saved!
# Epoch 32:
# Batch 415/415 | Loss: 3.0985
#
#     tr loss [3.1030] | val loss [2.9933] | lr [0.000288]
#
# Epoch 33:
# Batch 415/415 | Loss: 3.0988
#
#     tr loss [3.1014] | val loss [2.9995] | lr [0.000260]
#
# Epoch 34:
# Batch 415/415 | Loss: 3.0863
#
#     tr loss [3.0997] | val loss [2.9862] | lr [0.000233]
#
# Best model saved!
# Epoch 35:
# Batch 415/415 | Loss: 3.0750
#
#     tr loss [3.0973] | val loss [2.9906] | lr [0.000207]
#
# Epoch 36:
# Batch 415/415 | Loss: 3.1231
#
#     tr loss [3.0948] | val loss [2.9853] | lr [0.000182]
#
# Best model saved!
# Epoch 37:
# Batch 415/415 | Loss: 3.0959
#
#     tr loss [3.0926] | val loss [2.9902] | lr [0.000159]
#
# Epoch 38:
# Batch 415/415 | Loss: 3.0926
#
#     tr loss [3.0908] | val loss [2.9867] | lr [0.000136]
#
# Epoch 39:
# Batch 415/415 | Loss: 3.1152
#
#     tr loss [3.0904] | val loss [2.9857] | lr [0.000116]
#
# Epoch 40:
# Batch 415/415 | Loss: 3.0757
#
#     tr loss [3.0855] | val loss [2.9866] | lr [0.000096]
#
# Epoch 41:
# Batch 415/415 | Loss: 3.0861
#
#     tr loss [3.0866] | val loss [2.9873] | lr [0.000079]
#
# Epoch 42:
# Batch 415/415 | Loss: 3.1068
#
#     tr loss [3.0862] | val loss [2.9890] | lr [0.000063]
#
# Epoch 43:
# Batch 415/415 | Loss: 3.0704
#
#     tr loss [3.0841] | val loss [2.9870] | lr [0.000049]
#
# Epoch 44:
# Batch 415/415 | Loss: 3.0673
#
#     tr loss [3.0832] | val loss [2.9823] | lr [0.000036]
#
# Best model saved!
# Epoch 45:
# Batch 415/415 | Loss: 3.1012
#
#     tr loss [3.0843] | val loss [2.9827] | lr [0.000025]
#
# Epoch 46:
# Batch 415/415 | Loss: 3.0939
#
#     tr loss [3.0840] | val loss [2.9865] | lr [0.000017]
#
# Epoch 47:
# Batch 415/415 | Loss: 3.1017
#
#     tr loss [3.0820] | val loss [2.9824] | lr [0.000010]
#
# Epoch 48:
# Batch 415/415 | Loss: 3.0693
#
#     tr loss [3.0812] | val loss [2.9811] | lr [0.000005]
#
# Best model saved!
# Epoch 49:
# Batch 415/415 | Loss: 3.0869
#
#     tr loss [3.0790] | val loss [2.9823] | lr [0.000002]
#
# Epoch 50:
# Batch 415/415 | Loss: 3.0715
#
#     tr loss [3.0803] | val loss [2.9832] | lr [0.000001]
#
# Last model saved correctly
# End training after 474.3872 minutes

# %%
pd.DataFrame({'train_loss': history['train_loss'], 'val_loss': history['val_loss']}).plot()
# Out:
# <Axes: >

# %%
pd.DataFrame({'train_loss': history['train_loss']}).plot()
pd.DataFrame({'val_loss': history['val_loss']}).plot()
pd.DataFrame({'lr': history['lr']}).plot()
# Out:
# <Axes: >

# %%
loaded_model = SimCLRNet().to(device)
loaded_model.load_state_dict(
    torch.load('/kaggle/input/models/nawrozmohammadi/simclrnet-0-last/pytorch/default/1/simCLRNet_0_last_model.pth',
               weights_only=True, map_location=torch.device(device)))
loaded_model.eval()
# Out:
# SimCLRNet(
#   (encoder): ResNet(
#     (prep): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (block1): Sequential(
#       (0): ResidualBlock(
#         (doubleConve): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (skip): Identity()
#         (relu): ReLU(inplace=True)
#       )
#       (1): ResidualBlock(
#         (doubleConve): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (skip): Identity()
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (block2): Sequential(
#       (0): ResidualBlock(
#         (doubleConve): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (skip): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (1): ResidualBlock(
#         (doubleConve): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (skip): Identity()
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (block3): Sequential(
#       (0): ResidualBlock(
#         (doubleConve): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (skip): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (1): ResidualBlock(
#         (doubleConve): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (skip): Identity()
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (block4): Sequential(
#       (0): ResidualBlock(
#         (doubleConve): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (skip): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (1): ResidualBlock(
#         (doubleConve): Sequential(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (skip): Identity()
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (block5): Sequential(
#       (0): ResidualBlock(
#         (doubleConve): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (skip): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (head): Sequential(
#     (0): AdaptiveAvgPool2d(output_size=(1, 1))
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#   )
# )

# %%
# visualize feature maps or deeper layer activations to see how model is learning

layers = {
    "Block 1 (Low-level edges)": loaded_model.encoder.block1,
    "Block 2 (Textures)": loaded_model.encoder.block2,
    "Block 3 (Shapes)": loaded_model.encoder.block3,
    "Block 4 (High-level patterns)": loaded_model.encoder.block4,
}

# %%
activations = {}
handles = []
# Create hooks
def get_hook(name):
    def hook(module, input, output):
        activations[name] = output.detach()
    return hook

for name, layer in layers.items():
    handles.append(layer.register_forward_hook(get_hook(name))) # register and add to handles

# %%
 img, label = test_data.__getitem__(np.random.randint(len(test_data)))
org_img = img
org_img = np.array(org_img.cpu().permute(1,2,0))
#  denormalize
org_img = glb_std * org_img + glb_mean
org_img = np.clip(org_img, 0, 1)

plt.imshow(org_img)
plt.show()

img = img.unsqueeze(0).float().to(device)

loaded_model.eval()

with torch.no_grad():
    _ = loaded_model(img)


def plot_layer_features(feat_maps, title, n=8):
    fmap = feat_maps[0]  # [C, H, W]

    plt.figure(figsize=(15, 5))
    plt.suptitle(title, fontsize=14)

    for i in range(n):
        plt.subplot(2, 8, i + 1)
        plt.imshow(fmap[i].cpu())
        plt.axis("off")

    plt.tight_layout()
    plt.show()
for name in layers.keys():
    plot_layer_features(activations[name], name, n=8)
# Out:
# /tmp/ipykernel_58/3887675640.py:3: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   org_img = np.array(org_img.cpu().permute(1,2,0))

# %%
loaded_encoder = loaded_model.encoder # keep only encoder

# %%
# Freeze the encoder 
for p in loaded_encoder.block1.parameters(): p.requires_grad = False
for p in loaded_encoder.block2.parameters(): p.requires_grad = False
# for p in loaded_encoder.block3.parameters(): p.requires_grad = False

# %%
# Unfreeze the 3th block
for p in loaded_encoder.block3.parameters():
    p.requires_grad = True
    
# Unfreeze the 4th block
for p in loaded_encoder.block4.parameters():
    p.requires_grad = True
    
# Unfreeze the last block
for p in loaded_encoder.block5.parameters():
    p.requires_grad = True

# %%
class FoodClassifier(nn.Module):
    def __init__(self, encoder):
        super().__init__()

        self.encoder = loaded_encoder

        self.head = nn.Sequential(
            nn.AdaptiveAvgPool2d((1,1)),
            nn.Flatten(),
        
            nn.Linear(512, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.5),
        
            nn.Linear(1024, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            nn.Dropout(0.5),
        
            nn.Linear(512, 251)
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.head(x)
        return x
food_cls_base = FoodClassifier(loaded_encoder).to(device)
food_cls = food_cls_base
food_cls = torch.compile(food_cls)

# %%
trainable = sum(
    p.numel() for p in food_cls.parameters()
    if p.requires_grad
)

print(trainable)
# Out:
# 7481243

# %%
print(sum(p.requires_grad for p in loaded_encoder.parameters()))
# Out:
# 42

# %%
# Setup the model compiler
EPOCHS = 50
# optimizer = torch.optim.AdamW(food_cls.parameters(), lr=3e-4, weight_decay=1e-4) 
optimizer = torch.optim.AdamW([
    {"params": food_cls.head.parameters(), "lr": 3e-4},
    {"params": food_cls.encoder.block3.parameters(), "lr": 1e-6}, 
    {"params": food_cls.encoder.block4.parameters(), "lr": 5e-6}, 
    {"params": food_cls.encoder.block5.parameters(), "lr": 1e-6}
], weight_decay=5e-4)

# loss method 
loss_fun = nn.CrossEntropyLoss()

# per-epoch stepping
scheduler = CosineAnnealingLR(optimizer, T_max=EPOCHS, eta_min=1e-6)

# %%
# Create a training method for non-labeled data
scaler = torch.amp.GradScaler('cuda') # also speed up training 
def train_model(model, dataloader, loss_fun, optimizer):
  training_loss, total, correct = 0, 0, 0 
  model.train()
  # model.encoder.eval() # make sure that encoder is not changing  
    
  for batch, (X, y), in enumerate(dataloader):
    X, y = X.to(device), y.to(device)
    if y.ndim == 2:
        y = y.squeeze(1)
    y = y.long()
    optimizer.zero_grad(set_to_none=True) # reset the gradient

    # Enable aMP for the forward pass
    with torch.autocast(device_type="cuda", dtype=torch.float16):
        y_pred = model(X) # (B, C, H, W)
        loss = loss_fun(y_pred, y) # calculate the loss

    # scale loss and backpropagate
    scaler.scale(loss).backward() # comput the gradient
    scaler.step(optimizer) # update the weight
    scaler.update()
      
    training_loss += loss.item()
    # Calculate the training accuracy
    preds = torch.argmax(y_pred, dim=1)
    correct += (preds == y).sum().item()
    total += y.size(0) 
    
    if (batch+1 == len(dataloader)):
      print(f'Batch {batch+1}/{len(dataloader)} | Loss: {loss.item():.4f}')
  training_acc = correct / total 
  return training_loss/len(dataloader), training_acc,

# %%
# Create a validation method
def validate_model(model, dataloader, loss_fun, epoch):
  model.eval()
  val_loss, correct, total = 0, 0, 0
  with torch.no_grad():
    for batch, (X, y) in enumerate(dataloader):
      X, y = X.to(device), y.to(device)
      if y.ndim == 2:
        y = y.squeeze(1)
      y = y.long()

      # Enable AMP for the forward pass
      with torch.autocast(device_type="cuda", dtype=torch.float16):
          y_pred = model(X)
          loss = loss_fun(y_pred, y)
      val_loss += loss.item() 
      preds = torch.argmax(y_pred, dim=1)
      correct += (preds == y).sum().item()
      total += y.size(0)

    val_acc = correct/total
  return val_loss/len(dataloader), val_acc

# %%
# Check how many trainable parameters we have there shouldn't be encoder
for name, p in food_cls.named_parameters():
    if p.requires_grad:
        print(name)
# Out:
# _orig_mod.encoder.prep.0.weight
# _orig_mod.encoder.prep.1.weight
# _orig_mod.encoder.prep.1.bias
# _orig_mod.encoder.block3.0.doubleConve.0.weight
# _orig_mod.encoder.block3.0.doubleConve.1.weight
# _orig_mod.encoder.block3.0.doubleConve.1.bias
# _orig_mod.encoder.block3.0.doubleConve.3.weight
# _orig_mod.encoder.block3.0.doubleConve.4.weight
# _orig_mod.encoder.block3.0.doubleConve.4.bias
# _orig_mod.encoder.block3.0.skip.0.weight
# _orig_mod.encoder.block3.0.skip.1.weight
# _orig_mod.encoder.block3.0.skip.1.bias
# _orig_mod.encoder.block3.1.doubleConve.0.weight
# _orig_mod.encoder.block3.1.doubleConve.1.weight
# _orig_mod.encoder.block3.1.doubleConve.1.bias
# _orig_mod.encoder.block3.1.doubleConve.3.weight
# _orig_mod.encoder.block3.1.doubleConve.4.weight
# _orig_mod.encoder.block3.1.doubleConve.4.bias
# _orig_mod.encoder.block4.0.doubleConve.0.weight
# _orig_mod.encoder.block4.0.doubleConve.1.weight
# _orig_mod.encoder.block4.0.doubleConve.1.bias
# _orig_mod.encoder.block4.0.doubleConve.3.weight
# _orig_mod.encoder.block4.0.doubleConve.4.weight
# _orig_mod.encoder.block4.0.doubleConve.4.bias
# _orig_mod.encoder.block4.0.skip.0.weight
# _orig_mod.encoder.block4.0.skip.1.weight
# _orig_mod.encoder.block4.0.skip.1.bias
# _orig_mod.encoder.block4.1.doubleConve.0.weight
# _orig_mod.encoder.block4.1.doubleConve.1.weight
# _orig_mod.encoder.block4.1.doubleConve.1.bias
# _orig_mod.encoder.block4.1.doubleConve.3.weight
# _orig_mod.encoder.block4.1.doubleConve.4.weight
# _orig_mod.encoder.block4.1.doubleConve.4.bias
# _orig_mod.encoder.block5.0.doubleConve.0.weight
# _orig_mod.encoder.block5.0.doubleConve.1.weight
# _orig_mod.encoder.block5.0.doubleConve.1.bias
# _orig_mod.encoder.block5.0.doubleConve.3.weight
# _orig_mod.encoder.block5.0.doubleConve.4.weight
# _orig_mod.encoder.block5.0.doubleConve.4.bias
# _orig_mod.encoder.block5.0.skip.0.weight
# _orig_mod.encoder.block5.0.skip.1.weight
# _orig_mod.encoder.block5.0.skip.1.bias
# _orig_mod.head.2.weight
# _orig_mod.head.2.bias
# _orig_mod.head.3.weight
# _orig_mod.head.3.bias
# _orig_mod.head.6.weight
# _orig_mod.head.6.bias
# _orig_mod.head.7.weight
# _orig_mod.head.7.bias
# _orig_mod.head.10.weight
# _orig_mod.head.10.bias

# %%
output_path = "/kaggle/working"
history = {
    "train_loss": [],
    "train_acc": [],
    "val_loss": [],
    "val_acc": [], 
    "head_lr": [], 
    "encoder_lr": [], 
}
best_val_loss = float('inf')

patience, epochs_no_improve = 10, 0
best_val_acc = 0
start_train_time = time.time()
for i in range(EPOCHS):
    print(f'Epoch {i+1}:')
    tr_loss, tr_acc = train_model(food_cls, clf_train_loader, loss_fun, optimizer)
    history['train_acc'].append(tr_acc)
    history['train_loss'].append(tr_loss) 
    scheduler.step()

    val_loss, val_acc = validate_model(food_cls, clf_val_loader, loss_fun, i+1)
    history['val_acc'].append(val_acc)
    history['val_loss'].append(val_loss) 
    # history['head_lr'].append(optimizer.param_groups[0]['lr'])
    # history['encoder_lr'].append(optimizer.param_groups[1]['lr'])
    
    head_lr = optimizer.param_groups[0]['lr']
    encoder_lr = optimizer.param_groups[1]['lr']
    history['head_lr'].append(head_lr)
    history['encoder_lr'].append(encoder_lr)
    
    print(f"""
    tr loss [{tr_loss:.4f}] | val loss [{val_loss:.4f}]
    tr acc [{tr_acc:.4f}] | val acc [{val_acc:.4f}] |  [head lr [{head_lr:.6f}] | encoder lr [{encoder_lr:.6f}]
    """) 

    # Save only weights of the best model 
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        epochs_no_improve = 0
        torch.save(food_cls_base.state_dict(), f'{output_path}/food_cls_0_best_model_weights.pth')
        print("Best model saved!")
    else:
        epochs_no_improve += 1
        if epochs_no_improve >= patience:
            print(f"Early stopping at epoch {i+1}")
            break
torch.save(food_cls_base.state_dict(), f'{output_path}/food_cls_0_last_model.pth')
print(f'Last model saved correctly')
end_train_time = time.time()
print(f'End training after {(end_train_time - start_train_time)/60:.4f} minutes')
# Out:
# Epoch 1:
# W0709 22:40:42.587000 58 torch/_inductor/utils.py:1679] [0/0] Not enough SMs to use max_autotune_gemm mode
# Batch 415/415 | Loss: 5.1168
#
#     tr loss [5.1194] | val loss [4.7625]
#     tr acc [0.0362] | val acc [0.0714] |  [head lr [0.000300] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 2:
# Batch 415/415 | Loss: 4.4540
#
#     tr loss [4.6954] | val loss [4.5780]
#     tr acc [0.0658] | val acc [0.0849] |  [head lr [0.000299] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 3:
# Batch 415/415 | Loss: 4.3360
#
#     tr loss [4.5697] | val loss [4.5052]
#     tr acc [0.0817] | val acc [0.0918] |  [head lr [0.000297] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 4:
# Batch 415/415 | Loss: 4.3684
#
#     tr loss [4.4812] | val loss [4.4650]
#     tr acc [0.0867] | val acc [0.0988] |  [head lr [0.000295] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 5:
# Batch 415/415 | Loss: 4.7541
#
#     tr loss [4.4197] | val loss [4.4247]
#     tr acc [0.0916] | val acc [0.0998] |  [head lr [0.000293] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 6:
# Batch 415/415 | Loss: 4.3460
#
#     tr loss [4.3662] | val loss [4.4053]
#     tr acc [0.1017] | val acc [0.1003] |  [head lr [0.000290] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 7:
# Batch 415/415 | Loss: 4.2095
#
#     tr loss [4.3160] | val loss [4.3900]
#     tr acc [0.1037] | val acc [0.1060] |  [head lr [0.000286] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 8:
# Batch 415/415 | Loss: 4.1389
#
#     tr loss [4.2854] | val loss [4.3622]
#     tr acc [0.1101] | val acc [0.1092] |  [head lr [0.000282] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 9:
# Batch 415/415 | Loss: 4.3634
#
#     tr loss [4.2531] | val loss [4.3531]
#     tr acc [0.1111] | val acc [0.1122] |  [head lr [0.000277] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 10:
# Batch 415/415 | Loss: 4.2400
#
#     tr loss [4.2122] | val loss [4.3437]
#     tr acc [0.1192] | val acc [0.1157] |  [head lr [0.000271] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 11:
# Batch 415/415 | Loss: 4.2332
#
#     tr loss [4.1906] | val loss [4.3416]
#     tr acc [0.1217] | val acc [0.1151] |  [head lr [0.000266] | encoder lr [0.000001]
#
# Epoch 12:
# Batch 415/415 | Loss: 4.2026
#
#     tr loss [4.1760] | val loss [4.3290]
#     tr acc [0.1220] | val acc [0.1156] |  [head lr [0.000259] | encoder lr [0.000001]
#
# Epoch 13:
# Batch 415/415 | Loss: 3.9659
#
#     tr loss [4.1654] | val loss [4.3182]
#     tr acc [0.1265] | val acc [0.1169] |  [head lr [0.000253] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 14:
# Batch 415/415 | Loss: 3.8294
#
#     tr loss [4.1105] | val loss [4.3028]
#     tr acc [0.1335] | val acc [0.1199] |  [head lr [0.000246] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 15:
# Batch 415/415 | Loss: 4.1405
#
#     tr loss [4.0915] | val loss [4.2986]
#     tr acc [0.1340] | val acc [0.1227] |  [head lr [0.000238] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 16:
# Batch 415/415 | Loss: 4.2864
#
#     tr loss [4.0869] | val loss [4.2977]
#     tr acc [0.1328] | val acc [0.1215] |  [head lr [0.000231] | encoder lr [0.000001]
#
# Epoch 17:
# Batch 415/415 | Loss: 4.0655
#
#     tr loss [4.0594] | val loss [4.2882]
#     tr acc [0.1357] | val acc [0.1215] |  [head lr [0.000223] | encoder lr [0.000001]
#
# Epoch 18:
# Batch 415/415 | Loss: 3.8382
#
#     tr loss [4.0536] | val loss [4.2745]
#     tr acc [0.1355] | val acc [0.1285] |  [head lr [0.000214] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 19:
# Batch 415/415 | Loss: 4.0870
#
#     tr loss [4.0231] | val loss [4.2758]
#     tr acc [0.1421] | val acc [0.1273] |  [head lr [0.000206] | encoder lr [0.000001]
#
# Epoch 20:
# Batch 415/415 | Loss: 4.0861
#
#     tr loss [4.0065] | val loss [4.2661]
#     tr acc [0.1414] | val acc [0.1282] |  [head lr [0.000197] | encoder lr [0.000001]
#
# Epoch 21:
# Batch 415/415 | Loss: 3.8538
#
#     tr loss [4.0039] | val loss [4.2569]
#     tr acc [0.1453] | val acc [0.1264] |  [head lr [0.000188] | encoder lr [0.000001]
#
# Epoch 22:
# Batch 415/415 | Loss: 3.8779
#
#     tr loss [3.9711] | val loss [4.2513]
#     tr acc [0.1476] | val acc [0.1325] |  [head lr [0.000179] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 23:
# Batch 415/415 | Loss: 3.8846
#
#     tr loss [3.9524] | val loss [4.2501]
#     tr acc [0.1507] | val acc [0.1294] |  [head lr [0.000169] | encoder lr [0.000001]
#
# Epoch 24:
# Batch 415/415 | Loss: 4.1672
#
#     tr loss [3.9469] | val loss [4.2477]
#     tr acc [0.1507] | val acc [0.1287] |  [head lr [0.000160] | encoder lr [0.000001]
#
# Epoch 25:
# Batch 415/415 | Loss: 3.8820
#
#     tr loss [3.9106] | val loss [4.2423]
#     tr acc [0.1576] | val acc [0.1347] |  [head lr [0.000150] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 26:
# Batch 415/415 | Loss: 4.0973
#
#     tr loss [3.9207] | val loss [4.2367]
#     tr acc [0.1533] | val acc [0.1318] |  [head lr [0.000141] | encoder lr [0.000001]
#
# Epoch 27:
# Batch 415/415 | Loss: 4.0413
#
#     tr loss [3.9028] | val loss [4.2379]
#     tr acc [0.1595] | val acc [0.1346] |  [head lr [0.000132] | encoder lr [0.000001]
#
# Epoch 28:
# Batch 415/415 | Loss: 3.9034
#
#     tr loss [3.8741] | val loss [4.2410]
#     tr acc [0.1611] | val acc [0.1352] |  [head lr [0.000122] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 29:
# Batch 415/415 | Loss: 4.0460
#
#     tr loss [3.8776] | val loss [4.2287]
#     tr acc [0.1620] | val acc [0.1362] |  [head lr [0.000113] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 30:
# Batch 415/415 | Loss: 3.9027
#
#     tr loss [3.8598] | val loss [4.2307]
#     tr acc [0.1627] | val acc [0.1343] |  [head lr [0.000104] | encoder lr [0.000001]
#
# Epoch 31:
# Batch 415/415 | Loss: 3.8654
#
#     tr loss [3.8376] | val loss [4.2303]
#     tr acc [0.1654] | val acc [0.1370] |  [head lr [0.000095] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 32:
# Batch 415/415 | Loss: 3.6055
#
#     tr loss [3.8408] | val loss [4.2226]
#     tr acc [0.1624] | val acc [0.1375] |  [head lr [0.000087] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 33:
# Batch 415/415 | Loss: 3.5654
#
#     tr loss [3.8214] | val loss [4.2236]
#     tr acc [0.1688] | val acc [0.1387] |  [head lr [0.000078] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 34:
# Batch 415/415 | Loss: 3.4838
#
#     tr loss [3.8124] | val loss [4.2192]
#     tr acc [0.1726] | val acc [0.1379] |  [head lr [0.000070] | encoder lr [0.000001]
#
# Epoch 35:
# Batch 415/415 | Loss: 3.7386
#
#     tr loss [3.8088] | val loss [4.2194]
#     tr acc [0.1694] | val acc [0.1383] |  [head lr [0.000063] | encoder lr [0.000001]
#
# Epoch 36:
# Batch 415/415 | Loss: 3.6046
#
#     tr loss [3.7874] | val loss [4.2109]
#     tr acc [0.1725] | val acc [0.1396] |  [head lr [0.000055] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 37:
# Batch 415/415 | Loss: 4.0086
#
#     tr loss [3.7825] | val loss [4.2126]
#     tr acc [0.1771] | val acc [0.1404] |  [head lr [0.000048] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 38:
# Batch 415/415 | Loss: 3.8896
#
#     tr loss [3.7844] | val loss [4.2100]
#     tr acc [0.1764] | val acc [0.1410] |  [head lr [0.000042] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 39:
# Batch 415/415 | Loss: 3.8917
#
#     tr loss [3.7686] | val loss [4.2056]
#     tr acc [0.1747] | val acc [0.1425] |  [head lr [0.000035] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 40:
# Batch 415/415 | Loss: 3.8808
#
#     tr loss [3.7536] | val loss [4.2018]
#     tr acc [0.1745] | val acc [0.1435] |  [head lr [0.000030] | encoder lr [0.000001]
#
# Best model saved!
# Epoch 41:
# Batch 415/415 | Loss: 3.9223
#
#     tr loss [3.7781] | val loss [4.2035]
#     tr acc [0.1733] | val acc [0.1409] |  [head lr [0.000024] | encoder lr [0.000001]
#
# Epoch 42:
# Batch 415/415 | Loss: 4.0160
#
#     tr loss [3.7462] | val loss [4.2049]
#     tr acc [0.1818] | val acc [0.1415] |  [head lr [0.000019] | encoder lr [0.000001]
#
# Epoch 43:
# Batch 415/415 | Loss: 3.6178
#
#     tr loss [3.7566] | val loss [4.2000]
#     tr acc [0.1806] | val acc [0.1425] |  [head lr [0.000015] | encoder lr [0.000001]
#
# Epoch 44:
# Batch 415/415 | Loss: 4.1014
#
#     tr loss [3.7463] | val loss [4.1996]
#     tr acc [0.1793] | val acc [0.1411] |  [head lr [0.000011] | encoder lr [0.000001]
#
# Epoch 45:
# Batch 415/415 | Loss: 3.8717
#
#     tr loss [3.7539] | val loss [4.2002]
#     tr acc [0.1777] | val acc [0.1434] |  [head lr [0.000008] | encoder lr [0.000001]
#
# Epoch 46:
# Batch 415/415 | Loss: 3.6381
#
#     tr loss [3.7231] | val loss [4.1977]
#     tr acc [0.1797] | val acc [0.1416] |  [head lr [0.000006] | encoder lr [0.000001]
#
# Epoch 47:
# Batch 415/415 | Loss: 3.9262
#
#     tr loss [3.7428] | val loss [4.1999]
#     tr acc [0.1794] | val acc [0.1424] |  [head lr [0.000004] | encoder lr [0.000001]
#
# Epoch 48:
# Batch 415/415 | Loss: 3.7751
#
#     tr loss [3.7456] | val loss [4.1985]
#     tr acc [0.1800] | val acc [0.1421] |  [head lr [0.000002] | encoder lr [0.000001]
#
# Epoch 49:
# Batch 415/415 | Loss: 3.8313
#
#     tr loss [3.7529] | val loss [4.1995]
#     tr acc [0.1776] | val acc [0.1435] |  [head lr [0.000001] | encoder lr [0.000001]
#
# Epoch 50:
# Batch 415/415 | Loss: 3.6861
#
#     tr loss [3.7216] | val loss [4.1982]
#     tr acc [0.1851] | val acc [0.1442] |  [head lr [0.000001] | encoder lr [0.000001]
#
# Best model saved!
# Last model saved correctly
# End training after 195.6585 minutes

# %%
# Plot the learning curve 
pd.DataFrame({'tr_loss': history['train_loss'], 'val_loss': history['val_loss']}).plot()
pd.DataFrame({'tr_acc': history['train_acc'], 'val_acc': history['val_acc']}).plot()
pd.DataFrame({'head_lr': history['head_lr']}).plot()

# %% [markdown]
# ![loss_curve.png](attachment:d366da02-da23-4961-a2d5-c38deb8ec55e.png)

# %% [markdown]
# ![ChatGPT Image Jul 10, 2026, 08_22_51 AM.png](attachment:90bbc21e-34be-4671-8574-bd3127dd211f.png)

# %%
loaded_ssl_model = FoodClassifier(loaded_encoder).to(device)
loaded_ssl_model.load_state_dict(
    torch.load('/kaggle/working/food_cls_0_best_model_weights.pth',
               weights_only=True, map_location=torch.device(device)))
loaded_ssl_model.eval()

# %%
plt.figure(figsize=(15, 8))
for i in range(8):    
    img, label = test_data.__getitem__(np.random.randint(len(test_data)))
    
    img = img.unsqueeze(0).float().to(device)
    
    loaded_ssl_model.eval()
    
    loaded_ssl_model.eval()
    
    with torch.no_grad():
        y_pred = loaded_ssl_model(img)
    pred_label = y_pred.argmax(dim=1).item()
    img_np = img.squeeze(0).cpu().permute(1, 2, 0).numpy()
    #  denormalize
    img_np = glb_std * img_np + glb_mean
    img_np = np.clip(img_np, 0, 1)
    
    title_text = data_classes.iloc[label-1:label]['name'].values[0]
    pred_text = data_classes.iloc[pred_label-1:pred_label]['name'].values[0]
    
    plt.subplot(2, 4, i + 1)
    plt.imshow(img_np)
    plt.title(f'G:{title_text} | P:{pred_text}')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
all_preds = []
all_labels = []

# Evaluate mode on validation data
with torch.no_grad():
    for X, y in clf_val_loader:
        X = X.to(device)

        if y.ndim == 2:
            y = y.squeeze(1)

        outputs = loaded_ssl_model(X)
        preds = torch.argmax(outputs, dim=1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(y.numpy())

precision = precision_score(
    all_labels,
    all_preds,
    average='macro',
    zero_division=0
)

recall = recall_score(
    all_labels,
    all_preds,
    average='macro',
    zero_division=0
)

f1 = f1_score(
    all_labels,
    all_preds,
    average='macro',
    zero_division=0
)

print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")

# %% [markdown]
# | Precision | Recall |   F1 |
# | --------: | -----: | ---: |
# |      0.14 |   0.14 | 0.14 |
# |      0.18 |   0.12 | 0.14 |
# |      0.11 |   0.19 | 0.14 |
# |      0.23 |   0.10 | 0.14 |

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(12, 12))
plt.imshow(cm)
plt.colorbar()
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# %%
t_all_preds = []
t_all_labels = []

# Evaluate mode on test data
with torch.no_grad():
    for X, y in clf_test_loader:
        X = X.to(device)

        if y.ndim == 2:
            y = y.squeeze(1)

        outputs = loaded_ssl_model(X)
        preds = torch.argmax(outputs, dim=1)

        t_all_preds.extend(preds.cpu().numpy())
        t_all_labels.extend(y.numpy())

precision = precision_score(
    t_all_labels,
    t_all_preds,
    average='macro',
    zero_division=0
)

recall = recall_score(
    t_all_labels,
    t_all_preds,
    average='macro',
    zero_division=0
)

f1 = f1_score(
    t_all_labels,
    t_all_preds,
    average='macro',
    zero_division=0
)

print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")

# %%
cm = confusion_matrix(t_all_labels, t_all_preds)
plt.figure(figsize=(12, 12))
plt.imshow(cm)
plt.colorbar()
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
